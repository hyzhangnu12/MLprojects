# %% [markdown]
# # **Personalized Movie Recommender System Based on PySpark ALS Algorithm**

# %% [markdown]
# # **Part 0: Spark Environment Setup**

# %%
## update apt-get
# !apt-get update

## Install java
import os
# !apt-get install -y openjdk-8-jdk-headless -qq > /dev/null
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]
# !java -version

## Install pyspark
# !pip install pyspark==2.4.5

from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [95.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Get:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Packages [47.5 kB]
# Get:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [892 kB]
# Get:15 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,421 kB]
# Get:18 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [43.0 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,067 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [109 kB]
# Get:21 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,864 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [125 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [1,362 kB]
# Get:24 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [900 kB]
# Fetched 8,220 kB in 7s (1,227 kB/s)
# Reading package lists... Done
# openjdk version "1.8.0_265"
# OpenJDK Runtime Environment (build 1.8.0_265-8u265-b01-0ubuntu2~18.04-b01)
# OpenJDK 64-Bit Server VM (build 25.265-b01, mixed mode)
# Collecting pyspark==2.4.5
#   Downloading https://files.pythonhosted.org/packages/9a/5a/271c416c1c2185b6cb0151b29a91fff6fcaed80173c8584ff6d20e46b465/pyspark-2.4.5.tar.gz (217.8MB)
#      |████████████████████████████████| 217.8MB 62kB/s
# Collecting py4j==0.10.7
#   Downloading https://files.pythonhosted.org/packages/e3/53/c737818eb9a7dc32a7cd4f1396e787bd94200c3997c72c1dbe028587bd76/py4j-0.10.7-py2.py3-none-any.whl (197kB)
#      |████████████████████████████████| 204kB 45.2MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-2.4.5-py2.py3-none-any.whl size=218257928 sha256=c03e135c252d56fdc9f100e418377df31f876f65288fcf4d4fb2b486fde90805
#   Stored in directory: /root/.cache/pip/wheels/bf/db/04/61d66a5939364e756eb1c1be4ec5bdce6e04047fc7929a3c3c
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.7 pyspark-2.4.5

# %% [markdown]
# # **Part 1: Data Loading and Preprocessing**
# In this project, we train a recommender system over the [MovieLens](https://grouplens.org/datasets/movielens/latest/) dataset.

# %% [markdown]
# ## 1.1 Mount google drive

# %%
from google.colab import drive

drive.mount('ggdrive')
# Out:
# Drive already mounted at ggdrive; to attempt to forcibly remount, call drive.mount("ggdrive", force_remount=True).

# %% [markdown]
# ## 1.2 Read Data from google Drive

# %%
fpath_base = 'ggdrive/My Drive/dataSet/ml-latest-small'
dfs = {}

dfs['movies'] = spark.read.csv(f'{fpath_base}/movies.csv',inferSchema=True, header =True)
dfs['ratings'] = spark.read.csv(f'{fpath_base}/ratings.csv',inferSchema=True, header =True)
dfs['links'] = spark.read.csv(f'{fpath_base}/links.csv',inferSchema=True, header =True)
dfs['tags'] = spark.read.csv(f'{fpath_base}/tags.csv',inferSchema=True, header =True)

# %% [markdown]
# ## 1.3 Exploratory Data Analysis

# %% [markdown]
# ### 1.3.0 Necessary packages

# %%
import numpy as np
import pandas as pd
import pyspark.sql.functions as F
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### 1.3.1 Schema

# %%
for nm in dfs:
  print(f'data_{nm} Schema:')
  dfs[nm].printSchema()
# Out:
# data_movies Schema:
# root
#  |-- movieId: integer (nullable = true)
#  |-- title: string (nullable = true)
#  |-- genres: string (nullable = true)
#
# data_ratings Schema:
# root
#  |-- userId: integer (nullable = true)
#  |-- movieId: integer (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- timestamp: integer (nullable = true)
#
# data_links Schema:
# root
#  |-- movieId: integer (nullable = true)
#  |-- imdbId: integer (nullable = true)
#  |-- tmdbId: integer (nullable = true)
#
# data_tags Schema:
# root
#  |-- userId: integer (nullable = true)
#  |-- movieId: integer (nullable = true)
#  |-- tag: string (nullable = true)
#  |-- timestamp: integer (nullable = true)

# %% [markdown]
# ### 1.3.2 Basic Information

# %%
import pyspark.sql.functions as F

for nm in dfs:
  print(f'{"="*25} data_{nm} ({dfs[nm].count()} rows) {"="*25}')
  dfs[nm].show(10)
  print(f'{"-"*5} Number of missing values {"-"*5}')
  dfs[nm].select(*(F.sum(F.col(c).isNull().cast("int")).alias(c) for c in dfs[nm].columns)).show()
  print(f'{"-"*5} Number of unique values {"-"*5}')
  dfs[nm].agg(*(F.countDistinct(F.col(c)).alias(c) for c in dfs[nm].columns)).show()
# Out:
# ========================= data_movies (9742 rows) =========================
# +-------+--------------------+--------------------+
# |movieId|               title|              genres|
# +-------+--------------------+--------------------+
# |      1|    Toy Story (1995)|Adventure|Animati...|
# |      2|      Jumanji (1995)|Adventure|Childre...|
# |      3|Grumpier Old Men ...|      Comedy|Romance|
# |      4|Waiting to Exhale...|Comedy|Drama|Romance|
# |      5|Father of the Bri...|              Comedy|
# |      6|         Heat (1995)|Action|Crime|Thri...|
# |      7|      Sabrina (1995)|      Comedy|Romance|
# |      8| Tom and Huck (1995)|  Adventure|Children|
# |      9| Sudden Death (1995)|              Action|
# |     10|    GoldenEye (1995)|Action|Adventure|...|
# +-------+--------------------+--------------------+
# only showing top 10 rows
#
# ----- Number of missing values -----
# +-------+-----+------+
# |movieId|title|genres|
# +-------+-----+------+
# |      0|    0|     0|
# +-------+-----+------+
#
# ----- Number of unique values -----
# +-------+-----+------+
# |movieId|title|genres|
# +-------+-----+------+
# |   9742| 9737|   951|
# +-------+-----+------+
#
# ========================= data_ratings (100836 rows) =========================
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|      1|   4.0|964982703|
# |     1|      3|   4.0|964981247|
# |     1|      6|   4.0|964982224|
# |     1|     47|   5.0|964983815|
# |     1|     50|   5.0|964982931|
# |     1|     70|   3.0|964982400|
# |     1|    101|   5.0|964980868|
# |     1|    110|   4.0|964982176|
# |     1|    151|   5.0|964984041|
# |     1|    157|   5.0|964984100|
# +------+-------+------+---------+
# only showing top 10 rows
#
# ----- Number of missing values -----
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     0|      0|     0|        0|
# +------+-------+------+---------+
#
# ----- Number of unique values -----
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |   610|   9724|    10|    85043|
# +------+-------+------+---------+
#
# ========================= data_links (9742 rows) =========================
# +-------+------+------+
# |movieId|imdbId|tmdbId|
# +-------+------+------+
# |      1|114709|   862|
# |      2|113497|  8844|
# |      3|113228| 15602|
# |      4|114885| 31357|
# |      5|113041| 11862|
# |      6|113277|   949|
# |      7|114319| 11860|
# |      8|112302| 45325|
# |      9|114576|  9091|
# |     10|113189|   710|
# +-------+------+------+
# only showing top 10 rows
#
# ----- Number of missing values -----
# +-------+------+------+
# |movieId|imdbId|tmdbId|
# +-------+------+------+
# |      0|     0|     8|
# +-------+------+------+
#
# ----- Number of unique values -----
# +-------+------+------+
# |movieId|imdbId|tmdbId|
# +-------+------+------+
# |   9742|  9742|  9733|
# +-------+------+------+
#
# ========================= data_tags (3683 rows) =========================
# +------+-------+-----------------+----------+
# |userId|movieId|              tag| timestamp|
# +------+-------+-----------------+----------+
# |     2|  60756|            funny|1445714994|
# |     2|  60756|  Highly quotable|1445714996|
# |     2|  60756|     will ferrell|1445714992|
# |     2|  89774|     Boxing story|1445715207|
# |     2|  89774|              MMA|1445715200|
# |     2|  89774|        Tom Hardy|1445715205|
# |     2| 106782|            drugs|1445715054|
# |     2| 106782|Leonardo DiCaprio|1445715051|
# |     2| 106782|  Martin Scorsese|1445715056|
# |     7|  48516|     way too long|1169687325|
# +------+-------+-----------------+----------+
# only showing top 10 rows
#
# ----- Number of missing values -----
# +------+-------+---+---------+
# |userId|movieId|tag|timestamp|
# +------+-------+---+---------+
# |     0|      0|  0|        0|
# +------+-------+---+---------+
#
# ----- Number of unique values -----
# +------+-------+----+---------+
# |userId|movieId| tag|timestamp|
# +------+-------+----+---------+
# |    58|   1572|1589|     3411|
# +------+-------+----+---------+

# %% [markdown]
# ### 1.3.3 Rating matrix

# %%
# to check if there are duplicated ratings
print("duplicated ratings? ({})".format(dfs['ratings'].groupBy("userID", "movieID").count().count() != dfs['ratings'].count()))

rating_ratio = dfs['ratings'].count() / (dfs['ratings'].groupBy("userID").count().count() * dfs['ratings'].groupBy("movieID").count().count())
type(rating_ratio)
print("Only %.2f%% matrix cells have rating score." % (rating_ratio * 100))

rating_scores = dfs['ratings'].groupBy("rating").count().orderBy('rating')

print("\nrating scores info:\n"+"="*40)
rating_scores.show(rating_scores.count())
print("statistical info for rating scores:\n"+"="*40)
print(rating_scores.toPandas()['count'].describe())

print("\nstatistical distribution for the rating scores:\n"+"="*40)
fig = plt.figure(figsize=[15,4])
sns.barplot(x='rating', y='count', data=rating_scores.toPandas())
plt.title("Distribution of rating scores")
fig.show()
# Out:
# duplicated ratings? (False)
# Only 1.70% matrix cells have rating score.
#
# rating scores info:
# ========================================
# +------+-----+
# |rating|count|
# +------+-----+
# |   0.5| 1370|
# |   1.0| 2811|
# |   1.5| 1791|
# |   2.0| 7551|
# |   2.5| 5550|
# |   3.0|20047|
# |   3.5|13136|
# |   4.0|26818|
# |   4.5| 8551|
# |   5.0|13211|
# +------+-----+
#
# statistical info for rating scores:
# ========================================
# count       10.000000
# mean     10083.600000
# std       8335.389509
# min       1370.000000
# 25%       3495.750000
# 50%       8051.000000
# 75%      13192.250000
# max      26818.000000
# Name: count, dtype: float64
#
# statistical distribution for the rating scores:
# ========================================

# %% [markdown]
# #### Rating time distribution

# %%
from pyspark.sql.types import DateType

# transform rating timestamp to date
rating_mat = dfs['ratings'].withColumn('rating_date', F.from_unixtime('timestamp').cast(DateType()))
rating_mat.show(10, False)

# rating time range
rating_mat.select(F.min('rating_date'), F.max('rating_date')).show()

# number of ratings per day
rating_per_day = rating_mat.groupBy('rating_date').count().orderBy('rating_date').toPandas()
print(rating_per_day.head())

# visulize the rating time distribution
fig = plt.figure(figsize=[20, 5])
plt.step(rating_per_day['rating_date'], rating_per_day['count'], where='mid')
plt.xlabel('Date')
plt.ylabel('Number of ratings')
plt.title('Number of ratings per day')
plt.show()

rating_mat = rating_mat.toPandas()
# Out:
# +------+-------+------+---------+-----------+
# |userId|movieId|rating|timestamp|rating_date|
# +------+-------+------+---------+-----------+
# |1     |1      |4.0   |964982703|2000-07-30 |
# |1     |3      |4.0   |964981247|2000-07-30 |
# |1     |6      |4.0   |964982224|2000-07-30 |
# |1     |47     |5.0   |964983815|2000-07-30 |
# |1     |50     |5.0   |964982931|2000-07-30 |
# |1     |70     |3.0   |964982400|2000-07-30 |
# |1     |101    |5.0   |964980868|2000-07-30 |
# |1     |110    |4.0   |964982176|2000-07-30 |
# |1     |151    |5.0   |964984041|2000-07-30 |
# |1     |157    |5.0   |964984100|2000-07-30 |
# +------+-------+------+---------+-----------+
# only showing top 10 rows
#
# +----------------+----------------+
# |min(rating_date)|max(rating_date)|
# +----------------+----------------+
# |      1996-03-29|      2018-09-24|
# +----------------+----------------+
#
#   rating_date  count
# 0  1996-03-29     58
# 1  1996-04-12      9
# 2  1996-04-17     85
# 3  1996-04-18     53
# 4  1996-04-23     18

# %% [markdown]
# #### Jointplot

# %%
fig = plt.figure(figsize=[15, 15])
sns.jointplot(x='movieId', y='userId', data=rating_mat, kind='reg')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Heatmap

# %%
rating_heatmap = pd.pivot_table(rating_mat, index=['userId'],\
                                columns=['movieId'], values='rating', fill_value=0)
fig = plt.figure(figsize=[18, 15])
ax = sns.heatmap(rating_heatmap, cmap="coolwarm", center=2.5)
ax.set_title("Rating Table")
plt.show()

# %% [markdown]
# #### Rating statistical information

# %%
def ratingColInfo(col1='userId', col2='movieId', rating_mat=rating_mat):
  ratingCol = rating_mat.groupby(col1)['rating'].agg(['size', 'mean', 'std'])
  ratingCol.columns = [f'Number of {col2}', 'Rating score mean', 'Rating score std']
  print(ratingCol.iloc[:, 0].describe())
  fig, axs = plt.subplots(3, 1, figsize=[20, 15])
  for i, c in enumerate(ratingCol.columns):
    axs[i].plot(ratingCol.index, ratingCol[c], '.')
    axs[i].set_ylabel(c)
  _ = plt.xlabel(col1)
  return ratingCol

rating_userId = ratingColInfo()
# Out:
# count     610.000000
# mean      165.304918
# std       269.480584
# min        20.000000
# 25%        35.000000
# 50%        70.500000
# 75%       168.000000
# max      2698.000000
# Name: Number of movieId, dtype: float64

# %%
rating_movieId = ratingColInfo(col2='userId', col1='movieId')
# Out:
# count    9724.000000
# mean       10.369807
# std        22.401005
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         9.000000
# max       329.000000
# Name: Number of userId, dtype: float64

# %% [markdown]
# ### 1.3.4 Movies Features

# %%
movie_category = dfs['movies'].select('title', F.explode(F.split('genres', '\|')).alias('Category'))\
    .groupBy("Category")\
    .agg(F.count('title').alias('count'), F.collect_list('title').alias('titles'))\
    .orderBy('count', ascending=False)

print("# of movies for each category:\n"+"="*40)
movie_category.show(movie_category.count())
print("statistical info for movies numbers in each category:\n"+"="*40)
print(movie_category.toPandas()['count'].describe())

print("\n# of movies in each category:\n"+"="*40)
fig = plt.figure(figsize=[15,4])
sns.barplot(x='Category', y='count', data=movie_category.toPandas())
plt.title("# of movies in each category")
plt.xticks(rotation=60)
fig.show()
# Out:
# # of movies for each category:
# ========================================
# +------------------+-----+--------------------+
# |          Category|count|              titles|
# +------------------+-----+--------------------+
# |             Drama| 4361|[Waiting to Exhal...|
# |            Comedy| 3756|[Toy Story (1995)...|
# |          Thriller| 1894|[Heat (1995), Gol...|
# |            Action| 1828|[Heat (1995), Sud...|
# |           Romance| 1596|[Grumpier Old Men...|
# |         Adventure| 1263|[Toy Story (1995)...|
# |             Crime| 1199|[Heat (1995), Cas...|
# |            Sci-Fi|  980|[Powder (1995), C...|
# |            Horror|  978|[Dracula: Dead an...|
# |           Fantasy|  779|[Toy Story (1995)...|
# |          Children|  664|[Toy Story (1995)...|
# |         Animation|  611|[Toy Story (1995)...|
# |           Mystery|  573|[Copycat (1995), ...|
# |       Documentary|  440|[Nico Icon (1995)...|
# |               War|  382|[Richard III (199...|
# |           Musical|  334|[Pocahontas (1995...|
# |           Western|  167|[Desperado (1995)...|
# |              IMAX|  158|[Apollo 13 (1995)...|
# |         Film-Noir|   87|[Devil in a Blue ...|
# |(no genres listed)|   34|[La cravate (1957...|
# +------------------+-----+--------------------+
#
# statistical info for movies numbers in each category:
# ========================================
# count      20.000000
# mean     1104.200000
# std      1156.865984
# min        34.000000
# 25%       370.000000
# 50%       721.500000
# 75%      1346.250000
# max      4361.000000
# Name: count, dtype: float64
#
# # of movies in each category:
# ========================================

# %% [markdown]
# #### Unrated Movies

# %%
ratedID_set = set(dfs['ratings'].select('movieId').rdd.flatMap(lambda x: x).collect())
movies_unrated = dfs['movies'].filter(~F.col('movieID').isin(ratedID_set)).show()
# Out:
# +-------+--------------------+--------------------+
# |movieId|               title|              genres|
# +-------+--------------------+--------------------+
# |   1076|Innocents, The (1...|Drama|Horror|Thri...|
# |   2939|      Niagara (1953)|      Drama|Thriller|
# |   3338|For All Mankind (...|         Documentary|
# |   3456|Color of Paradise...|               Drama|
# |   4194|I Know Where I'm ...|   Drama|Romance|War|
# |   5721|  Chosen, The (1981)|               Drama|
# |   6668|Road Home, The (W...|       Drama|Romance|
# |   6849|      Scrooge (1970)|Drama|Fantasy|Mus...|
# |   7020|        Proof (1991)|Comedy|Drama|Romance|
# |   7792|Parallax View, Th...|            Thriller|
# |   8765|This Gun for Hire...|Crime|Film-Noir|T...|
# |  25855|Roaring Twenties,...|Crime|Drama|Thriller|
# |  26085|Mutiny on the Bou...|Adventure|Drama|R...|
# |  30892|In the Realms of ...|Animation|Documen...|
# |  32160|Twentieth Century...|              Comedy|
# |  32371|Call Northside 77...|Crime|Drama|Film-...|
# |  34482|Browning Version,...|               Drama|
# |  85565|  Chalet Girl (2011)|      Comedy|Romance|
# +-------+--------------------+--------------------+

# %% [markdown]
# ## 1.4 Data type conversion

# %%
from pyspark.sql.types import IntegerType, FloatType, DateType

sdf_rating = dfs['ratings'].withColumn('rating_date', F.from_unixtime('timestamp').cast(DateType()))\
    .select(F.col('userID').cast(IntegerType()).alias('userID'),
            F.col('movieID').cast(IntegerType()).alias('movieID'),
            F.col('rating').cast(FloatType()).alias('rating'),
            'rating_date', 'timestamp')

sdf_rating.show()
# Out:
# +------+-------+------+-----------+---------+
# |userID|movieID|rating|rating_date|timestamp|
# +------+-------+------+-----------+---------+
# |     1|      1|   4.0| 2000-07-30|964982703|
# |     1|      3|   4.0| 2000-07-30|964981247|
# |     1|      6|   4.0| 2000-07-30|964982224|
# |     1|     47|   5.0| 2000-07-30|964983815|
# |     1|     50|   5.0| 2000-07-30|964982931|
# |     1|     70|   3.0| 2000-07-30|964982400|
# |     1|    101|   5.0| 2000-07-30|964980868|
# |     1|    110|   4.0| 2000-07-30|964982176|
# |     1|    151|   5.0| 2000-07-30|964984041|
# |     1|    157|   5.0| 2000-07-30|964984100|
# |     1|    163|   5.0| 2000-07-30|964983650|
# |     1|    216|   5.0| 2000-07-30|964981208|
# |     1|    223|   3.0| 2000-07-30|964980985|
# |     1|    231|   5.0| 2000-07-30|964981179|
# |     1|    235|   4.0| 2000-07-30|964980908|
# |     1|    260|   5.0| 2000-07-30|964981680|
# |     1|    296|   3.0| 2000-07-30|964982967|
# |     1|    316|   3.0| 2000-07-30|964982310|
# |     1|    333|   5.0| 2000-07-30|964981179|
# |     1|    349|   4.0| 2000-07-30|964982563|
# +------+-------+------+-----------+---------+
# only showing top 20 rows

# %% [markdown]
# # **Part 2: Spark ALS (Alternating Least Squares) model**

# %% [markdown]
# ## 2.1 Model building and training

# %% [markdown]
# ### 2.1.1 Packages

# %%
from pyspark.ml.recommendation import ALS
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.evaluation import RegressionEvaluator

# %% [markdown]
# ### 2.1.2 Split training and testing dataset

# %%
# Random split
#(training, testing) = sdf_rating.randomSplit([0.8, 0.2])

# Split along rating time
ts1 = sdf_rating.approxQuantile("timestamp", [0.8], 0)[0]
#print(ts1)
training = sdf_rating.filter(F.col('timestamp') <= ts1)
testing = sdf_rating.filter(F.col('timestamp') > ts1)

print('Percentage of training data: %.2f%%' % (training.count()/(training.count()+testing.count()) * 100))
assert training.count()+testing.count() == sdf_rating.count()
# Out:
# Percentage of training data: 80.00%

# %% [markdown]
# ### 2.1.3 ALS model instance

# %%
als = ALS(userCol="userID", itemCol="movieID", ratingCol="rating", coldStartStrategy="drop")

# %% [markdown]
# ### 2.1.4 Tune model using ParamGridBuilder

# %%
paragrid = ParamGridBuilder()\
    .addGrid(als.maxIter, [5, 10, 20])\
    .addGrid(als.rank, [6, 8, 10, 12, 14])\
    .addGrid(als.regParam, [0.01, 0.05, 0.1, 0.5, 1.0])\
    .build()

# %% [markdown]
# ### 2.1.5 Define evaluator as RMSE

# %%
RMSE_eval = RegressionEvaluator(metricName='rmse', labelCol='rating', predictionCol='prediction')

# %% [markdown]
# ### 2.1.6 Build Cross Validation

# %%
crossval = CrossValidator(estimator=als,
                          estimatorParamMaps=paragrid,
                          evaluator=RMSE_eval,
                          numFolds=3,
                          collectSubModels=True,
                          seed=42)

# %% [markdown]
# ### 2.1.7 Fit ALS model to training data

# %%
cv_models = crossval.fit(training)

# %% [markdown]
# ## 2.2 Model evaluation

# %% [markdown]
# ### 2.2.1 Training 'history'

# %%
params = [{p.name: v for p, v in m.items()} for m in cv_models.getEstimatorParamMaps()]
#print(params)

fitting_params = pd.DataFrame.from_dict([
    {cv_models.getEvaluator().getMetricName(): metric, **ps} 
    for ps, metric in zip(params, cv_models.avgMetrics)])
print(fitting_params)

g = sns.FacetGrid(fitting_params, row="maxIter", hue='rank', height=3, aspect=4)
g = g.map(plt.plot, 'regParam', 'rmse', marker='o').add_legend()
# Out:
#         rmse  maxIter  rank  regParam
# 0   1.081302        5     6      0.01
# 1   0.974660        5     6      0.05
# 2   0.919819        5     6      0.10
# 3   1.008871        5     6      0.50
# 4   1.325351        5     6      1.00
# ..       ...      ...   ...       ...
# 70  1.292450       20    14      0.01
# 71  0.990483       20    14      0.05
# 72  0.911355       20    14      0.10
# 73  1.011333       20    14      0.50
# 74  1.325229       20    14      1.00
#
# [75 rows x 4 columns]

# %% [markdown]
# ### 2.2.2 Best model

# %%
best_model = cv_models.bestModel
params_best = {"rank": best_model.rank,
               "maxIter": best_model._java_obj.parent().getMaxIter(),
               "regParam": best_model._java_obj.parent().getRegParam()}

print(f'Params of the best model is:\n{params_best}')
# Out:
# Params of the best model is:
# {'rank': 6, 'maxIter': 20, 'regParam': 0.1}

# %%
#params_best = {'rank': 6, 'maxIter': 20, 'regParam': 0.1}

# %% [markdown]
# ### 2.2.3 Model performance over testing

# %%
test_pred = best_model.transform(testing)
print(f"RMSE_testing = {RMSE_eval.evaluate(test_pred)}")
test_pred.show()
# Out:
# RMSE_testing = 0.9315303760018631
# +------+-------+------+-----------+----------+----------+
# |userID|movieID|rating|rating_date| timestamp|prediction|
# +------+-------+------+-----------+----------+----------+
# |   233|   1580|   3.0| 2018-06-18|1529334057|  3.210842|
# |   495|   1580|   3.5| 2016-03-22|1458635792| 4.0059953|
# |   495|   1645|   5.0| 2016-03-22|1458635970|  4.005345|
# |   298|   4900|   2.5| 2016-07-02|1467489493| 2.8832438|
# |    18|  32460|   3.5| 2017-04-21|1492805550|  4.344365|
# |   414|  44022|   2.5| 2017-03-15|1489548300| 3.1610792|
# |   414|  96488|   4.5| 2018-04-01|1522624379| 4.0274906|
# |    18|  96488|   4.0| 2018-01-09|1515532582| 4.0839953|
# |   233|    858|   4.0| 2018-04-26|1524781360| 3.9334896|
# |    15|    858|   4.0| 2017-11-13|1510571941|  4.932226|
# |   601|   1721|   4.0| 2018-03-18|1521398191|  3.704467|
# |   233|   1721|   3.5| 2018-06-18|1529334058| 3.1395957|
# |   495|   1721|   5.0| 2016-03-22|1458635859| 3.2808602|
# |   601|  48780|   4.5| 2018-03-19|1521467750| 4.4258075|
# |    15|  48780|   4.5| 2017-11-13|1510572075|  4.398642|
# |   511|  56941|   4.0| 2018-03-27|1522154660| 3.2664626|
# |   495|  69481|   4.5| 2016-03-22|1458636595|  4.430339|
# |    15|   1270|   5.0| 2017-11-13|1510571953| 3.8755357|
# |   298|   2572|   2.5| 2016-10-16|1476632985| 2.0289361|
# |   601|   3000|   4.0| 2018-03-19|1521467860|  4.646453|
# +------+-------+------+-----------+----------+----------+
# only showing top 20 rows

# %% [markdown]
# ### 2.2.4 Re-fitting model with best super-parameters and the whole dataset

# %%
als = ALS(userCol='userID', itemCol='movieID', ratingCol='rating',
          coldStartStrategy='drop', **params_best)
best_model = als.fit(sdf_rating)

preds = best_model.transform(sdf_rating)
print(f'RMSE = {RMSE_eval.evaluate(preds)}')

preds = preds.withColumn('round_pred', F.round(F.col('prediction') * 2)/2)
preds.show()
# Out:
# RMSE = 0.6385618346649153
# +------+-------+------+-----------+----------+----------+----------+
# |userID|movieID|rating|rating_date| timestamp|prediction|round_pred|
# +------+-------+------+-----------+----------+----------+----------+
# |   191|    148|   5.0| 1996-04-17| 829760897| 4.9098005|       5.0|
# |   133|    471|   4.0| 1996-09-23| 843491793| 3.2227645|       3.0|
# |   597|    471|   2.0| 1999-11-02| 941558175| 4.0155573|       4.0|
# |   385|    471|   4.0| 1996-12-16| 850766697| 3.1905313|       3.0|
# |   436|    471|   3.0| 1996-05-31| 833530187| 3.5122488|       3.5|
# |   602|    471|   4.0| 1996-08-24| 840876085| 3.4073892|       3.5|
# |    91|    471|   1.0| 2005-04-05|1112713817| 2.5311131|       2.5|
# |   409|    471|   3.0| 2000-09-02| 967912821|  3.352325|       3.5|
# |   372|    471|   3.0| 1997-09-16| 874415126|  2.670897|       2.5|
# |   599|    471|   2.5| 2017-06-26|1498518822| 2.8257911|       3.0|
# |   603|    471|   4.0| 2000-03-31| 954482443| 3.4692287|       3.5|
# |   182|    471|   4.5| 2003-06-05|1054779644|  3.747856|       3.5|
# |   218|    471|   4.0| 2005-03-24|1111624874|   3.70712|       3.5|
# |   474|    471|   3.0| 2000-11-19| 974668858| 3.3773003|       3.5|
# |   500|    471|   1.0| 2001-11-12|1005528017| 1.9231174|       2.0|
# |    57|    471|   3.0| 2000-09-24| 969753604| 3.5559847|       3.5|
# |   462|    471|   2.5| 2005-08-12|1123890831| 2.6168337|       2.5|
# |   387|    471|   3.0| 2006-02-04|1139047519| 3.0705297|       3.0|
# |   610|    471|   4.0| 2016-11-19|1479544381| 3.5708256|       3.5|
# |   217|    471|   2.0| 2000-04-17| 955943727|  2.845848|       3.0|
# +------+-------+------+-----------+----------+----------+----------+
# only showing top 20 rows

# %% [markdown]
# #### Performance over each movie

# %%
msePred_movie = preds.groupBy('movieID')\
    .agg(F.mean((F.col('rating') - F.col('round_pred'))**2).alias('msePred_of_movie'),
         F.count('rating').alias('#rators_of_movie'))

fig = plt.figure(figsize=[10,6])
sns.scatterplot(x='#rators_of_movie', y='msePred_of_movie', data=msePred_movie.toPandas())
plt.title("Prediction mse for each movie vs. Number of rators of the movie")
fig.show()

# %% [markdown]
# #### Performance over each user

# %%
msePred_user = preds.groupBy('userID')\
    .agg(F.mean((F.col('rating') - F.col('round_pred'))**2).alias('msePred_of_user'),
         F.count('rating').alias('#rators_of_user'))

fig = plt.figure(figsize=[10,6])
sns.scatterplot(x='#rators_of_user', y='msePred_of_user', data=msePred_user.toPandas())
plt.title("Prediction mse for each user vs. Number of movies the user rated")
fig.show()

# %% [markdown]
# # **Part 3: Personalized Movie Recommendation**

# %% [markdown]
# ## 3.1 Movie properties table

# %%
dfs['movies'].show(10, truncate=False)
dfs['links'].show(10, truncate=False)
# Out:
# +-------+----------------------------------+-------------------------------------------+
# |movieId|title                             |genres                                     |
# +-------+----------------------------------+-------------------------------------------+
# |1      |Toy Story (1995)                  |Adventure|Animation|Children|Comedy|Fantasy|
# |2      |Jumanji (1995)                    |Adventure|Children|Fantasy                 |
# |3      |Grumpier Old Men (1995)           |Comedy|Romance                             |
# |4      |Waiting to Exhale (1995)          |Comedy|Drama|Romance                       |
# |5      |Father of the Bride Part II (1995)|Comedy                                     |
# |6      |Heat (1995)                       |Action|Crime|Thriller                      |
# |7      |Sabrina (1995)                    |Comedy|Romance                             |
# |8      |Tom and Huck (1995)               |Adventure|Children                         |
# |9      |Sudden Death (1995)               |Action                                     |
# |10     |GoldenEye (1995)                  |Action|Adventure|Thriller                  |
# +-------+----------------------------------+-------------------------------------------+
# only showing top 10 rows
#
# +-------+------+------+
# |movieId|imdbId|tmdbId|
# +-------+------+------+
# |1      |114709|862   |
# |2      |113497|8844  |
# |3      |113228|15602 |
# |4      |114885|31357 |
# |5      |113041|11862 |
# |6      |113277|949   |
# |7      |114319|11860 |
# |8      |112302|45325 |
# |9      |114576|9091  |
# |10     |113189|710   |
# +-------+------+------+
# only showing top 10 rows

# %% [markdown]
# ### 3.1.1 Split title into title and release_year

# %%
import re
from pyspark.sql.types import StructType, StructField, StringType, ArrayType

def title_split(title):
  res = re.search('\(\d{4}\)', title)
  if res:
    return title[:res.start()-1], int(res.group()[1:5])
  else:
    print(f'The movie title "{title}" not in a good format')
    return title, 1000

udf_title_split = F.udf(title_split, StructType([StructField('title', StringType(), True),
                                                 StructField('release_year', IntegerType(), True)]))
#title_split('abc ( 1995)')

# %% [markdown]
# ### 3.1.2 Transform genres into list

# %%
udf_genres_list = F.udf(lambda x: x.lower().split('|'), ArrayType(StringType()))

# %% [markdown]
# ### 3.1.3 Movie_tab

# %%
movie_tab = dfs['movies'].select('movieId', udf_title_split('title').title.alias('title'),\
                                 udf_title_split('title').release_year.alias('release_year'),\
                                 #udf_genres_list('genres').alias('genres'))
                                 'genres')
movie_tab.show(10, truncate=False)
# Out:
# +-------+---------------------------+------------+-------------------------------------------+
# |movieId|title                      |release_year|genres                                     |
# +-------+---------------------------+------------+-------------------------------------------+
# |1      |Toy Story                  |1995        |Adventure|Animation|Children|Comedy|Fantasy|
# |2      |Jumanji                    |1995        |Adventure|Children|Fantasy                 |
# |3      |Grumpier Old Men           |1995        |Comedy|Romance                             |
# |4      |Waiting to Exhale          |1995        |Comedy|Drama|Romance                       |
# |5      |Father of the Bride Part II|1995        |Comedy                                     |
# |6      |Heat                       |1995        |Action|Crime|Thriller                      |
# |7      |Sabrina                    |1995        |Comedy|Romance                             |
# |8      |Tom and Huck               |1995        |Adventure|Children                         |
# |9      |Sudden Death               |1995        |Action                                     |
# |10     |GoldenEye                  |1995        |Action|Adventure|Thriller                  |
# +-------+---------------------------+------------+-------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# ### 3.1.4 Merge TMDBid

# %%
movie_tab = movie_tab.join(dfs['links'].drop('imdbId'), on=['movieId'], how='left')
movie_tab.show(10, truncate=False)
# Out:
# +-------+---------------------------+------------+-------------------------------------------+------+
# |movieId|title                      |release_year|genres                                     |tmdbId|
# +-------+---------------------------+------------+-------------------------------------------+------+
# |1      |Toy Story                  |1995        |Adventure|Animation|Children|Comedy|Fantasy|862   |
# |2      |Jumanji                    |1995        |Adventure|Children|Fantasy                 |8844  |
# |3      |Grumpier Old Men           |1995        |Comedy|Romance                             |15602 |
# |4      |Waiting to Exhale          |1995        |Comedy|Drama|Romance                       |31357 |
# |5      |Father of the Bride Part II|1995        |Comedy                                     |11862 |
# |6      |Heat                       |1995        |Action|Crime|Thriller                      |949   |
# |7      |Sabrina                    |1995        |Comedy|Romance                             |11860 |
# |8      |Tom and Huck               |1995        |Adventure|Children                         |45325 |
# |9      |Sudden Death               |1995        |Action                                     |9091  |
# |10     |GoldenEye                  |1995        |Action|Adventure|Thriller                  |710   |
# +-------+---------------------------+------------+-------------------------------------------+------+
# only showing top 10 rows

# %% [markdown]
# ### 3.1.5 Display movie poster using TMDB API

# %%
# !pip install tmdbsimple
import tmdbsimple as tmdb
from IPython.display import Image, display, HTML

#tmdb.API_KEY = 'YOU_KEY'

def movie_poster(df_recom):
  my_html = "<table border=0><tr>"
  for i in range(df_recom.shape[0]):
    img_alt = df_recom.iloc[i]['title']
    try:
      image_path = 'not-a-real.jpg'
      poster_path = tmdb.Movies(df_recom.iloc[i]['tmdbId']).info()['poster_path']
      image_path = f"https://image.tmdb.org/t/p/w500{poster_path}"
      my_html += f'<td><img src={image_path} width=200></img></td>'
    except Exception:
      my_html += f'<td><img src={image_path} alt="{img_alt}" width=200></img></td>'
      #print(f"No movie posters for {img_alt}")
    if i % 5 == 4:
      my_html += '</tr><tr>'
  my_html += '</tr></table>'
  #print(my_html)
  display(HTML(my_html))
# Out:
# Collecting tmdbsimple
#   Downloading https://files.pythonhosted.org/packages/bb/9e/0a40a653f250568a1452cc79063953cbd78e64871827c3d0e1b2dbcebb89/tmdbsimple-2.6.6-py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from tmdbsimple) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (3.0.4)
# Installing collected packages: tmdbsimple
# Successfully installed tmdbsimple-2.6.6

# %% [markdown]
# ### 3.1.6 Highest rated movies

# %%
recom_popu = sdf_rating.groupBy('movieId').agg({'rating': 'mean'})\
             .join(movie_tab, on=['movieId'], how='left')\
             .orderBy(['avg(rating)', 'release_year'], ascending=False)

# %% [markdown]
# ## 3.2 Recommend movies to specific users

# %%
from pyspark.ml.linalg import Vectors, DenseVector

def recom_user(userId, n_recom=10, genres=None):
  user_fact = best_model.userFactors.filter(F.col('id') == userId)
  if user_fact.count() != 1:
    print(f'{"="*10} Welcome, new user-{userId}! Here are our most popular movies: {"="*10}')
    recom_tab = recom_popu
    if genres:
      recom_tab.filter(F.col('genres').contains(genres))
    recom_tab.show(n_recom, truncate=False)
    movie_poster(recom_tab.limit(n_recom).toPandas())
  else:
    user_fact = Vectors.dense(user_fact.take(1)[0]['features'])
    dot_prod_udf = F.udf(lambda v: float(Vectors.dense(v).dot(user_fact)), FloatType())
    pred_tab = best_model.itemFactors.withColumn('predict', dot_prod_udf(F.col('features')))
    pred_tab = pred_tab.select(F.col('id').alias('movieId'), 'predict')\
               .join(movie_tab, on=['movieId'], how='left')
    
    history_tab = sdf_rating.filter(F.col('userId') == userId)\
                  .select('movieId', 'rating', 'rating_date')\
                  .join(pred_tab, on=['movieId'], how='left')\
                  .orderBy(['rating', 'rating_date'], ascending=False)
    print(f'{"="*10} Welcome back, user-{userId}! Here are the movies you had highly rated recently: {"="*10}')
    history_tab.show(n_recom, truncate=False)
    movie_poster(history_tab.limit(n_recom).toPandas())

    rated_m = set(history_tab.select('movieId').rdd.flatMap(lambda x: x).collect())
    recom_tab = pred_tab.filter(~F.col('movieId').isin(rated_m))
    if genres:
      recom_tab = recom_tab.filter(F.col('genres').contains(genres))
    recom_tab = recom_tab.orderBy('predict', ascending=False)
    print(f'\n{"="*10} Here are the movies I recommend to you: {"="*10}')
    recom_tab.show(n_recom, truncate=False)
    movie_poster(recom_tab.limit(n_recom).toPandas())

# %% [markdown]
# ### 3.2.1 Recommend movie to userId "-575"

# %%
recom_user(-575)
# Out:
# ========== Welcome, new user--575! Here are our most popular movies: ==========
# +-------+-----------+------------------------------+------------+-----------------------------------+------+
# |movieId|avg(rating)|title                         |release_year|genres                             |tmdbId|
# +-------+-----------+------------------------------+------------+-----------------------------------+------+
# |187717 |5.0        |Won't You Be My Neighbor?     |2018        |Documentary                        |490003|
# |172705 |5.0        |Tickling Giants               |2017        |Documentary                        |390319|
# |179133 |5.0        |Loving Vincent                |2017        |Animation|Crime|Drama              |339877|
# |167064 |5.0        |I Am Not Your Negro           |2017        |Documentary                        |411019|
# |179135 |5.0        |Blue Planet II                |2017        |Documentary                        |463612|
# |156025 |5.0        |Ice Age: The Great Egg-Scapade|2016        |Adventure|Animation|Children|Comedy|387893|
# |160644 |5.0        |Indignation                   |2016        |Drama                              |340611|
# |158882 |5.0        |All Yours                     |2016        |Comedy|Drama|Romance               |387398|
# |158027 |5.0        |SORI: Voice from the Heart    |2016        |Drama|Sci-Fi                       |380254|
# |164367 |5.0        |The Girl with All the Gifts   |2016        |Drama|Horror|Sci-Fi|Thriller       |375366|
# +-------+-----------+------------------------------+------------+-----------------------------------+------+
# only showing top 10 rows
# <table border=0><tr><td><img src=https://image.tmdb.org/t/p/w500/8qE8NZjiP2M884baH0VoLF828Vp.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/7NlURmIhGaRuRukWfDg8KNj3oup.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/56sq57kDm7XgyXBYrgJLumo0Jac.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/zwd0Zti7BvY1mO0mTPzM0fRrtc6.jpg width=200></img></td><td><img src=not-a-real.jpg alt="Blue Planet II" width=200></img></td></tr><tr><td><img src=https://image.tmdb.org/t/p/w500/aA1qqjZE7bUGf6IuudJT6lXjU6I.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/vdCD8z55a4RNmHQDPIpuMFqoY2B.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/ybQ2vE5MiwKAB5RlS845srubCSM.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/lvdA0NAqOJRC5peafUDRPhP88yY.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/ysQqYp9G37Q114Nc6uvCHbDmaj6.jpg width=200></img></td></tr><tr></tr></table>

# %% [markdown]
# ### 3.2.2 Recommend movie to userId "575"

# %%
recom_user(575)
# Out:
# ========== Welcome back, user-575! Here are the movies you had highly rated recently: ==========
# +-------+------+-----------+---------+-----------------------------------------------+------------+---------------------------+------+
# |movieId|rating|rating_date|predict  |title                                          |release_year|genres                     |tmdbId|
# +-------+------+-----------+---------+-----------------------------------------------+------------+---------------------------+------+
# |2622   |5.0   |1999-05-12 |4.0116196|William Shakespeare's A Midsummer Night's Dream|1999        |Comedy|Fantasy             |10210 |
# |1259   |5.0   |1999-05-12 |4.33397  |Stand by Me                                    |1986        |Adventure|Drama            |235   |
# |296    |5.0   |1999-05-12 |4.6710024|Pulp Fiction                                   |1994        |Comedy|Crime|Drama|Thriller|680   |
# |430    |5.0   |1999-05-12 |4.5746007|Calendar Girl                                  |1993        |Comedy|Drama               |117553|
# |2542   |5.0   |1999-05-12 |4.3132896|Lock, Stock & Two Smoking Barrels              |1998        |Comedy|Crime|Thriller      |100   |
# |2598   |4.0   |1999-05-12 |3.4350579|Pushing Tin                                    |1999        |Comedy                     |12596 |
# |2580   |4.0   |1999-05-12 |3.9953337|Go                                             |1999        |Comedy|Crime               |9430  |
# |2567   |4.0   |1999-05-12 |3.247517 |EDtv                                           |1999        |Comedy                     |11374 |
# |2583   |4.0   |1999-05-12 |3.5089653|Cookie's Fortune                               |1999        |Comedy|Drama               |9465  |
# |2571   |4.0   |1999-05-12 |4.364358 |Matrix, The                                    |1999        |Action|Sci-Fi|Thriller     |603   |
# +-------+------+-----------+---------+-----------------------------------------------+------------+---------------------------+------+
# only showing top 10 rows
# <table border=0><tr><td><img src=https://image.tmdb.org/t/p/w500/8kSerJrhrJWKLk1LViesGcnrUPE.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/xujr3IVkGfSq3xTnwnPCCeBzh7h.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/vz0w9BSehcqjDcJOjRaCk7fgJe7.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/e5vzxBLagSoFh3LCA2zSj55AVc7.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/ljSqZTl5oophHsH1Qtyv7AF2BW6.jpg width=200></img></td></tr><tr><td><img src=https://image.tmdb.org/t/p/w500/xnnjoMONNamGU6ZX6acbcxyOKv1.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/wm85zKhZEXmY9BMJUVx8hoo3Ovp.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/3ZCLVOfEyGowLWsgOF4vn6vjRsJ.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/dXNAPwY7VrqMAo51EKhhCJfaGb5.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/hphavCiwhpDTDVZ5ElkbV0sEnux.jpg width=200></img></td></tr><tr></tr></table>
# ========== Here are the movies I recommend to you: ==========
# +-------+---------+-----------------------------------------------------------+------------+---------------------+------+
# |movieId|predict  |title                                                      |release_year|genres               |tmdbId|
# +-------+---------+-----------------------------------------------------------+------------+---------------------+------+
# |26171  |5.799065 |Play Time (a.k.a. Playtime)                                |1967        |Comedy               |10227 |
# |59018  |5.605727 |Visitor, The                                               |2007        |Drama|Romance        |12473 |
# |60943  |5.605727 |Frozen River                                               |2008        |Drama                |10183 |
# |27611  |5.5219336|Battlestar Galactica                                       |2003        |Drama|Sci-Fi|War     |206216|
# |7841   |5.4105973|Children of Dune                                           |2003        |Fantasy|Sci-Fi       |192936|
# |3379   |5.361603 |On the Beach                                               |1959        |Drama                |35412 |
# |4437   |5.1606283|Suspiria                                                   |1977        |Horror               |11906 |
# |2070   |5.1352186|Tender Mercies                                             |1983        |Drama|Romance|Western|42121 |
# |7842   |5.1163325|Dune                                                       |2000        |Drama|Fantasy|Sci-Fi |876   |
# |32892  |5.1127577|Ivan's Childhood (a.k.a. My Name is Ivan) (Ivanovo detstvo)|1962        |Drama|War            |31442 |
# +-------+---------+-----------------------------------------------------------+------------+---------------------+------+
# only showing top 10 rows
# <table border=0><tr><td><img src=https://image.tmdb.org/t/p/w500/wrB3jP6xKFwywLDPBHBDBcITLKu.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/qZRcN4JLwYQWTxKlycZPLQb37mO.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/9XRRSD7swlYrGBhZ8vOR2yngIKZ.jpg width=200></img></td><td><img src=not-a-real.jpg alt="Battlestar Galactica" width=200></img></td><td><img src=not-a-real.jpg alt="Children of Dune" width=200></img></td></tr><tr><td><img src=https://image.tmdb.org/t/p/w500/lTDuj5zalrI0fpQel7UfPHTexTK.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/5ya8jTbNZTrCFUx9OwpNBjCivXY.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/pkAOhgIt2CLyJaVpFYywe1EPNf.jpg width=200></img></td><td><img src=not-a-real.jpg alt="Dune" width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/vmRWSLP1DE9WTta0hfzIafJ0dID.jpg width=200></img></td></tr><tr></tr></table>

# %% [markdown]
# ### 3.2.3 Recommend movie to userId "232"

# %%
recom_user(232, genres='Sci-Fi')
# Out:
# ========== Welcome back, user-232! Here are the movies you had highly rated recently: ==========
# +-------+------+-----------+---------+--------------------+------------+------------------------------------------------+------+
# |movieId|rating|rating_date|predict  |title               |release_year|genres                                          |tmdbId|
# +-------+------+-----------+---------+--------------------+------------+------------------------------------------------+------+
# |81591  |5.0   |2011-01-07 |3.2988863|Black Swan          |2010        |Drama|Thriller                                  |44214 |
# |79132  |5.0   |2010-08-30 |3.9242601|Inception           |2010        |Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX |27205 |
# |78499  |5.0   |2010-08-30 |3.870197 |Toy Story 3         |2010        |Adventure|Animation|Children|Comedy|Fantasy|IMAX|10193 |
# |2329   |5.0   |2010-07-11 |4.041191 |American History X  |1998        |Crime|Drama                                     |73    |
# |69757  |5.0   |2010-03-24 |3.8235164|(500) Days of Summer|2009        |Comedy|Drama|Romance                            |19913 |
# |68358  |5.0   |2009-07-10 |3.7687006|Star Trek           |2009        |Action|Adventure|Sci-Fi|IMAX                    |13475 |
# |2028   |5.0   |2009-05-08 |4.0391536|Saving Private Ryan |1998        |Action|Drama|War                                |857   |
# |296    |5.0   |2009-05-08 |3.953345 |Pulp Fiction        |1994        |Comedy|Crime|Drama|Thriller                     |680   |
# |2762   |5.0   |2008-08-08 |3.7048426|Sixth Sense, The    |1999        |Drama|Horror|Mystery                            |745   |
# |3147   |5.0   |2008-08-08 |4.0247874|Green Mile, The     |1999        |Crime|Drama                                     |497   |
# +-------+------+-----------+---------+--------------------+------------+------------------------------------------------+------+
# only showing top 10 rows
# <table border=0><tr><td><img src=https://image.tmdb.org/t/p/w500/rH19vkjAzCZ0HIUvrgB3rowm68h.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/4cpGytCB0eqvRks4FAlJoUJiFPG.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/c2gsmSQ2Cqv8zosqKOCwRS0GFBS.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/f9mbM0YMLpYemcWx6o2WeiYQLDP.jpg width=200></img></td></tr><tr><td><img src=https://image.tmdb.org/t/p/w500/hN2ZtF3Uw6mhIHZiqL0SKzELtKn.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/1wY4psJ5NVEhCuOYROwLH2XExM2.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/e5vzxBLagSoFh3LCA2zSj55AVc7.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/fIssD3w3SvIhPPmVo4WMgZDVLID.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/velWPhVMQeQKcxggNEU8YmIo52R.jpg width=200></img></td></tr><tr></tr></table>
# ========== Here are the movies I recommend to you: ==========
# +-------+---------+-------------------------------------------------------+------------+-------------------------------------+------+
# |movieId|predict  |title                                                  |release_year|genres                               |tmdbId|
# +-------+---------+-------------------------------------------------------+------------+-------------------------------------+------+
# |104780 |4.5239725|Mystery of the Third Planet, The (Tayna tretey planety)|1981        |Adventure|Animation|Sci-Fi           |49802 |
# |3687   |4.5239725|Light Years (Gandahar)                                 |1988        |Adventure|Animation|Fantasy|Sci-Fi   |22500 |
# |26849  |4.5239725|Stand, The                                             |1994        |Adventure|Drama|Fantasy|Horror|Sci-Fi|13519 |
# |27611  |4.3732595|Battlestar Galactica                                   |2003        |Drama|Sci-Fi|War                     |206216|
# |2495   |4.3348503|Fantastic Planet, The (Planète sauvage, La)            |1973        |Animation|Sci-Fi                     |16306 |
# |4454   |4.332758 |More                                                   |1998        |Animation|Drama|Sci-Fi|IMAX          |36107 |
# |94810  |4.2878437|Eva                                                    |2011        |Drama|Fantasy|Sci-Fi                 |77561 |
# |7841   |4.236458 |Children of Dune                                       |2003        |Fantasy|Sci-Fi                       |192936|
# |128991 |4.2156706|Johnny Express                                         |2014        |Animation|Comedy|Sci-Fi              |269711|
# |112804 |4.209304 |I Origins                                              |2014        |Drama|Sci-Fi                         |244267|
# +-------+---------+-------------------------------------------------------+------------+-------------------------------------+------+
# only showing top 10 rows
# <table border=0><tr><td><img src=https://image.tmdb.org/t/p/w500/936c9E1fs8Tzz485J0jtJqKaggx.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/AaarQvo20v6Ggz7gN5YxYt51aDo.jpg width=200></img></td><td><img src=not-a-real.jpg alt="Stand, The" width=200></img></td><td><img src=not-a-real.jpg alt="Battlestar Galactica" width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/prq0j1S0K07UjwLZLF6oMGflRUI.jpg width=200></img></td></tr><tr><td><img src=https://image.tmdb.org/t/p/w500/cj7UBhfTl1XS5wQQSOU9KwsQLQa.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/9GH6VRhwI5SrD178aqPCI1Xpf4P.jpg width=200></img></td><td><img src=not-a-real.jpg alt="Children of Dune" width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/11ZzBm4uGiEKSPQYuirW1EdMuBv.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/eszXrE5W3UaK3oer9s8U63OklTa.jpg width=200></img></td></tr><tr></tr></table>

# %% [markdown]
# ## 3.3 Find the similar moives for input moive

# %%
def recom_movie(movieId, n_recom=10, genres=None):
  curr_movie = movie_tab.filter(F.col('movieId') == movieId)
  if curr_movie.count() != 1:
    print(f'Sorry, the movie you input is not in our system.\nPlease input correct movieId next time.')
    return
  else:
    print(f'{"="*10} Welcome, here is the movie you input:')
    curr_movie.show(truncate=False)
    movie_poster(curr_movie.toPandas())

  movie_fact = best_model.itemFactors.filter(F.col('id') == movieId)
  if movie_fact.count() != 1:
    print(f'{"="*10} The movie-{movieId} you input is a movie we havn"t receive rating yet! {"="*10}')
    print(f'{" "*10} Here I recommend you our most popular movies: {" "*10}')
    recom_tab = recom_popu
    if genres:
      recom_tab.filter(F.col('genres').contains(genres))
    recom_tab.show(n_recom, truncate=False)
    movie_poster(recom_tab.limit(n_recom).toPandas())
  else:
    np_m = np.array(movie_fact.select('features').collect()).reshape(-1, 1)
    np_userF = np.squeeze(np.array(best_model.userFactors.select('features').collect()))
    pred_m = np.dot(np_userF, np_m).reshape(1, -1)
    pred_m = pred_m / np.linalg.norm(pred_m)
    #print(pred_m.shape)

    def cosSim(x):
      np_x = np.array(x).reshape(-1, 1)
      pred_x = np.dot(np_userF, np_x)
      return float(np.dot(pred_m, pred_x) / np.linalg.norm(pred_x))
    udf_cosSim = F.udf(cosSim, FloatType())

    sim_tab = best_model.itemFactors.select(F.col('id').alias('movieId'),\
                                            udf_cosSim(F.col('features')).alias('cosSim'))\
              .join(movie_tab, on=['movieId'], how='left')
    if genres:
      sim_tab = sim_tab.filter(F.col('genres').contains(genres))
    sim_tab = sim_tab.orderBy('cosSim', ascending=False)
    print(f'\n{"="*10} Here are the movies which are most similar to the one you input: {"="*10}')
    sim_tab.show(n_recom, truncate=False)
    movie_poster(sim_tab.limit(n_recom).toPandas())

# %% [markdown]
# ### 3.3.1 Similar movies for movieId "463"

# %%
recom_movie(463)
# Out:
# Sorry, the movie you input is not in our system.
# Please input correct movieId next time.

# %% [markdown]
# ### 3.3.2 Similar movies for movieId "471"

# %%
recom_movie(471)
# Out:
# ========== Welcome, here is the movie you input:
# +-------+--------------------+------------+------+------+
# |movieId|title               |release_year|genres|tmdbId|
# +-------+--------------------+------------+------+------+
# |471    |Hudsucker Proxy, The|1994        |Comedy|11934 |
# +-------+--------------------+------------+------+------+
# <table border=0><tr><td><img src=https://image.tmdb.org/t/p/w500/g1kAfnNjdL280HZyqPHypBGLO45.jpg width=200></img></td></tr></table>
# ========== Here are the movies which are most similar to the one you input: ==========
# +-------+----------+-----------------------------------+------------+----------------------+------+
# |movieId|cosSim    |title                              |release_year|genres                |tmdbId|
# +-------+----------+-----------------------------------+------------+----------------------+------+
# |471    |1.0       |Hudsucker Proxy, The               |1994        |Comedy                |11934 |
# |2896   |0.99888253|Alvarez Kelly                      |1966        |Western               |60285 |
# |32289  |0.9988034 |Ice Princess                       |2005        |Children|Comedy|Drama |13374 |
# |918    |0.9983387 |Meet Me in St. Louis               |1944        |Musical               |909   |
# |351    |0.9983255 |Corrina, Corrina                   |1994        |Comedy|Drama|Romance  |10464 |
# |46967  |0.9982955 |Scoop                              |2006        |Comedy|Fantasy|Mystery|512   |
# |943    |0.99823487|Ghost and Mrs. Muir, The           |1947        |Drama|Fantasy|Romance |22292 |
# |77881  |0.99790597|Lovers & Leavers (Kuutamolla)      |2002        |Drama|Romance         |21245 |
# |79299  |0.99790597|No. 1 Ladies' Detective Agency, The|2008        |Comedy|Crime|Mystery  |null  |
# |79536  |0.99790597|Hellsinki (Rööperi)                |2009        |Crime                 |25335 |
# +-------+----------+-----------------------------------+------------+----------------------+------+
# only showing top 10 rows
# <table border=0><tr><td><img src=https://image.tmdb.org/t/p/w500/g1kAfnNjdL280HZyqPHypBGLO45.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/coJriPRR32il0ABBUjCTvhXI5Zf.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/zEfI4zu4pQrgc08Jh9Vv2FpELvO.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/aPGcAYwFGNdfkHQnuLnxNBY9AiS.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/t0wI2CuqP745ZFOTufIDdPoz2fa.jpg width=200></img></td></tr><tr><td><img src=https://image.tmdb.org/t/p/w500/aHvZYoQNRTMrfs46pj64b9GrbaK.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/aFdHBIEj0ehjpEHRAUdXT1MJxum.jpg width=200></img></td><td><img src=not-a-real.jpg alt="No. 1 Ladies' Detective Agency, The" width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/ktl6AKjgfg8GiwKwBDLEmFXrkZj.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/rVqjmU9zBnDszSGzUZ5leYq1ZSB.jpg width=200></img></td></tr><tr></tr></table>

# %% [markdown]
# ### 3.3.3 Similar movies for movieId "2628"

# %%
recom_movie(2628, genres='Sci-Fi')
# Out:
# ========== Welcome, here is the movie you input:
# +-------+-----------------------------------------+------------+-----------------------+------+
# |movieId|title                                    |release_year|genres                 |tmdbId|
# +-------+-----------------------------------------+------------+-----------------------+------+
# |2628   |Star Wars: Episode I - The Phantom Menace|1999        |Action|Adventure|Sci-Fi|1893  |
# +-------+-----------------------------------------+------------+-----------------------+------+
# <table border=0><tr><td><img src=https://image.tmdb.org/t/p/w500/6wkfovpn7Eq8dYNKaG5PY3q2oq6.jpg width=200></img></td></tr></table>
# ========== Here are the movies which are most similar to the one you input: ==========
# +-------+----------+--------------------------------------------+------------+--------------------------------------+------+
# |movieId|cosSim    |title                                       |release_year|genres                                |tmdbId|
# +-------+----------+--------------------------------------------+------------+--------------------------------------+------+
# |2628   |1.0       |Star Wars: Episode I - The Phantom Menace   |1999        |Action|Adventure|Sci-Fi               |1893  |
# |101864 |0.99941385|Oblivion                                    |2013        |Action|Adventure|Sci-Fi|IMAX          |75612 |
# |34150  |0.99939734|Fantastic Four                              |2005        |Action|Adventure|Sci-Fi               |9738  |
# |60037  |0.99902254|Happening, The                              |2008        |Drama|Sci-Fi|Thriller                 |8645  |
# |184253 |0.9990174 |The Cloverfield Paradox                     |2018        |Horror|Mystery|Sci-Fi|Thriller        |384521|
# |8361   |0.9988309 |Day After Tomorrow, The                     |2004        |Action|Adventure|Drama|Sci-Fi|Thriller|435   |
# |34319  |0.99868625|Island, The                                 |2005        |Action|Sci-Fi|Thriller                |1635  |
# |292    |0.9985263 |Outbreak                                    |1995        |Action|Drama|Sci-Fi|Thriller          |6950  |
# |5378   |0.9983956 |Star Wars: Episode II - Attack of the Clones|2002        |Action|Adventure|Sci-Fi|IMAX          |1894  |
# |6934   |0.99838686|Matrix Revolutions, The                     |2003        |Action|Adventure|Sci-Fi|Thriller|IMAX |605   |
# +-------+----------+--------------------------------------------+------------+--------------------------------------+------+
# only showing top 10 rows
# <table border=0><tr><td><img src=https://image.tmdb.org/t/p/w500/6wkfovpn7Eq8dYNKaG5PY3q2oq6.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/2ncs7hqBsEjFMqt6Y7ShBCO9tWs.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/8HLQLILZLhDQWO6JDpvY6XJLH75.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/v1Cw6WaCjNqInpAzUwbXB4LGgoX.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/dJe4s2h9hac0Fu3pQVV4OuWe8kU.jpg width=200></img></td></tr><tr><td><img src=https://image.tmdb.org/t/p/w500/kX8qKXc4XR8pu7e8iUL574zgrci.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/qU9dDBfGTfSEPTkBIrUaCU2Rwu4.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/4KymNvlWR0XF0sqX2BWRd9Z3yXR.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/oZNPzxqM2s5DyVWab09NTQScDQt.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/fgm8OZ7o4G1G1I9EeGcb85Noe6L.jpg width=200></img></td></tr><tr></tr></table>

# %% [markdown]
# ### 3.3.4 Similar movies for movieId "4194"

# %%
recom_movie(4194, genres='Sci-Fi')
# Out:
# ========== Welcome, here is the movie you input:
# +-------+-----------------------+------------+-----------------+------+
# |movieId|title                  |release_year|genres           |tmdbId|
# +-------+-----------------------+------------+-----------------+------+
# |4194   |I Know Where I'm Going!|1945        |Drama|Romance|War|56137 |
# +-------+-----------------------+------------+-----------------+------+
# <table border=0><tr><td><img src=https://image.tmdb.org/t/p/w500/i0Tq9xHqjlm3TjMYAJEq3hFnpQb.jpg width=200></img></td></tr></table>
# ========== The movie-4194 you input is a movie we havn"t receive rating yet! ==========
#            Here I recommend you our most popular movies:
# +-------+-----------+------------------------------+------------+-----------------------------------+------+
# |movieId|avg(rating)|title                         |release_year|genres                             |tmdbId|
# +-------+-----------+------------------------------+------------+-----------------------------------+------+
# |187717 |5.0        |Won't You Be My Neighbor?     |2018        |Documentary                        |490003|
# |179135 |5.0        |Blue Planet II                |2017        |Documentary                        |463612|
# |172705 |5.0        |Tickling Giants               |2017        |Documentary                        |390319|
# |179133 |5.0        |Loving Vincent                |2017        |Animation|Crime|Drama              |339877|
# |167064 |5.0        |I Am Not Your Negro           |2017        |Documentary                        |411019|
# |158027 |5.0        |SORI: Voice from the Heart    |2016        |Drama|Sci-Fi                       |380254|
# |160644 |5.0        |Indignation                   |2016        |Drama                              |340611|
# |158882 |5.0        |All Yours                     |2016        |Comedy|Drama|Romance               |387398|
# |164367 |5.0        |The Girl with All the Gifts   |2016        |Drama|Horror|Sci-Fi|Thriller       |375366|
# |156025 |5.0        |Ice Age: The Great Egg-Scapade|2016        |Adventure|Animation|Children|Comedy|387893|
# +-------+-----------+------------------------------+------------+-----------------------------------+------+
# only showing top 10 rows
# <table border=0><tr><td><img src=https://image.tmdb.org/t/p/w500/8qE8NZjiP2M884baH0VoLF828Vp.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/56sq57kDm7XgyXBYrgJLumo0Jac.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/7NlURmIhGaRuRukWfDg8KNj3oup.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/zwd0Zti7BvY1mO0mTPzM0fRrtc6.jpg width=200></img></td><td><img src=not-a-real.jpg alt="Blue Planet II" width=200></img></td></tr><tr><td><img src=https://image.tmdb.org/t/p/w500/aA1qqjZE7bUGf6IuudJT6lXjU6I.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/lvdA0NAqOJRC5peafUDRPhP88yY.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/ysQqYp9G37Q114Nc6uvCHbDmaj6.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/ybQ2vE5MiwKAB5RlS845srubCSM.jpg width=200></img></td><td><img src=https://image.tmdb.org/t/p/w500/vdCD8z55a4RNmHQDPIpuMFqoY2B.jpg width=200></img></td></tr><tr></tr></table>
